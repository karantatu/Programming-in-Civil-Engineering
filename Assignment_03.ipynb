# %% [markdown]
# # Assignment 03
# Q1
#
# ---

# %%
#Calcutation on Lenth of transition Curve
V = int(input("Enter the value of desing speed:"))
R = int(input("Enter the value of Radius of curvature:"))
N = float(input("Enter the value of Slope:"))
W = float(input("Enter the value of width of road including extra widening:"))
emax = float(input("enter the value for plain terrain:"))

#Velocity m/s
v = V*(5/18)
Rv = round(v , 3)
print("Velocity in m/s = ",Rv)
ecal = (V*V/(225*R))
Recal = round(ecal,3)
print ("The Value of Super elevation:",Recal)if ecal>emax else print(emax)
Ls = (emax*N*W/2)
RLs = round(Ls,3)
print("Lenth of transition curve Ls =",RLs)
# Out:
# Enter the value of desing speed:65
# Enter the value of Radius of curvature:220
# Enter the value of Slope:150
# Enter the value of width of road including extra widening:7.5
# enter the value for plain terrain:0.07
# Velocity in m/s =  18.056
# The Value of Super elevation: 0.085
# Lenth of transition curve Ls = 39.375

# %% [markdown]
# Q2
#
# ---

# %%
# Find Thickness of Pavement
R = int(input("Constant R:"))
C = int(input("Constant C:"))

import numpy as geek
A = int(input("Total Data Values for EWL Constant:"))
B = int(input("Total Data Values for AADT:"))

EWL_Constant = []
AADT =[]

for i in range (1, A+1):
  print("Enter EWL Constant:")
  A = float(input())
  EWL_Constant.append(A)

for j in range (1, B+1):
  print('Enter AADT:')
  B = float(input())
  AADT.append(B)

product = geek.dot(EWL_Constant, AADT)
#Print("DOt Product : \n", product)
Total_EWL = round(product,3)
print("Total EWL :", Total_EWL)
print("Total EWL after 60 years :", Total_EWL*1.6)

TI = 1.35*(((1.6*Total_EWL)+((product)/2))**0.11)
RTI = round(TI,3)
print("Traffic Index :",RTI)

Thickness = 0.166*TI*(99-R)/(C**0.2)
RThickness = round(Thickness,3)
print("Thickness of Pavement :",RThickness,"cm")
# Out:
# Constant R:48
# Constant C:16
# Total Data Values for EWL Constant:4
# Total Data Values for AADT:4
# Enter EWL Constant:
# 330
# Enter EWL Constant:
# 1070
# Enter EWL Constant:
# 2460
# Enter EWL Constant:
# 4620
# Enter AADT:
# 3750
# Enter AADT:
# 470
# Enter AADT:
# 320
# Enter AADT:
# 120
# Total EWL : 3082000.0
# Total EWL after 60 years : 4931200.0
# Traffic Index : 7.578
# Thickness of Pavement : 36.847 cm

# %% [markdown]
# Q3
#
# ---

# %%
#CBR Test
P = float(input("Load in kg :"))
p = float(input("Tyre pressure kg/cm^2 :"))
M = int(input("Total Number of Layers in given Pavement :"))
Thick = float(input("Bituminous surface Thickness :"))
pi = 3.14159
CBR = []

for i in range (1,M+1):
  print("California Bearing Ratio of Material in % :")
  CBR_Value = float(input())
  CBR.append(CBR_Value)
  T = ((1.75*P)/(CBR_Value)-(P/(p*pi)))**0.5
  RT = round(T,3)
  print("Thickness Above this layer :",RT,"cm")

print("Bituminous surface Thickness :",Thick,"cm")
# Out:
# Load in kg :4085
# Tyre pressure kg/cm^2 :7
# Total Number of Layers in given Pavement :3
# Bituminous surface Thickness :4
# California Bearing Ratio of Material in % :
# 4.38
# Thickness Above this layer : 38.031 cm
# California Bearing Ratio of Material in % :
# 6
# Thickness Above this layer : 31.713 cm
# California Bearing Ratio of Material in % :
# 12
# Thickness Above this layer : 20.248 cm
# Bituminous surface Thickness : 4.0 cm
